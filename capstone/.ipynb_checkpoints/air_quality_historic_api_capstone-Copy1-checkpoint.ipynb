# %%
import requests
import json
import pandas as pd

# Define the base URL for the POST request
url = 'https://data.airquality.nsw.gov.au/api/Data/get_Observations'

# Construct the payload as described in the API documentation
payload = {
    "Parameters": ["PM10","PM2.5","CO","NH3", "NO","NO2","SO2", "OZONE","TSPd" # Air quality parameter
                   ,"SOLAR","TEMP","SD1","WDR","WSP", "Humid", 'NEPH'],                       
    "Sites": [39],   # List of site IDs
    "StartDate": "2015-4-01",                    # Start date for the query
    "EndDate": "2015-5-01",                      # End date for the query
    "Categories": ["Averages"],                   # Data categories
    "SubCategories": ["Hourly"],                  # Subcategories (Hourly data)
    "Frequency": ["Hourly Average"]  # Frequency
}

# Set the headers for the request, if required
headers = {
    'Content-Type': 'application/json'  # API expects a JSON payload
}

# Make the POST request
response = requests.post(url, headers=headers, data=json.dumps(payload))

# Check if the request was successful
if response.status_code == 200:
    # Parse the response JSON
    data = response.json()
    
    # Convert the JSON data to a DataFrame
    df = pd.DataFrame(data)

else:
    # Print the error if the request failed
    print(f"Error: {response.status_code} - {response.text}")

# %%
df.head()
# Out:
#    Site_Id                                          Parameter        Date  \
# 0       39  {'ParameterCode': 'CO', 'ParameterDescription'...  2015-04-01
# 1       39  {'ParameterCode': 'HUMID', 'ParameterDescripti...  2015-04-01
# 2       39  {'ParameterCode': 'NEPH', 'ParameterDescriptio...  2015-04-01
# 3       39  {'ParameterCode': 'NO', 'ParameterDescription'...  2015-04-01
# 4       39  {'ParameterCode': 'NO2', 'ParameterDescription...  2015-04-01
#
#    Hour HourDescription      Value AirQualityCategory DeterminingPollutant
# 0     1    12 am - 1 am   0.754289               None                 None
# 1     1    12 am - 1 am  94.199000               None                 None
# 2     1    12 am - 1 am   0.232000               None                 None
# 3     1    12 am - 1 am   6.026604               None                 None
# 4     1    12 am - 1 am   1.959503               GOOD                 None

# %%
df.tail()
# Out:
#        Site_Id                                          Parameter        Date  \
# 10075       39  {'ParameterCode': 'SO2', 'ParameterDescription...  2015-04-30
# 10076       39  {'ParameterCode': 'SOLAR', 'ParameterDescripti...  2015-04-30
# 10077       39  {'ParameterCode': 'TEMP', 'ParameterDescriptio...  2015-04-30
# 10078       39  {'ParameterCode': 'WDR', 'ParameterDescription...  2015-04-30
# 10079       39  {'ParameterCode': 'WSP', 'ParameterDescription...  2015-04-30
#
#        Hour HourDescription       Value AirQualityCategory  \
# 10075    24   11 pm - 12 am    0.034686               GOOD
# 10076    24   11 pm - 12 am  -14.142000               None
# 10077    24   11 pm - 12 am   16.094000               None
# 10078    24   11 pm - 12 am  231.690000               None
# 10079    24   11 pm - 12 am    0.369000               None
#
#       DeterminingPollutant
# 10075                 None
# 10076                 None
# 10077                 None
# 10078                 None
# 10079                 None

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10080 entries, 0 to 10079
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Site_Id               10080 non-null  int64
#  1   Parameter             10080 non-null  object
#  2   Date                  10080 non-null  object
#  3   Hour                  10080 non-null  int64
#  4   HourDescription       10080 non-null  object
#  5   Value                 9873 non-null   float64
#  6   AirQualityCategory    3489 non-null   object
#  7   DeterminingPollutant  0 non-null      object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 630.1+ KB

# %%
import requests
import json
import pandas as pd
from datetime import datetime, timedelta
import time  # Import the time module for adding sleep

# Define the base URL for the POST request
url = 'https://data.airquality.nsw.gov.au/api/Data/get_Observations'

# Initialize an empty DataFrame to store the combined data
combined_df = pd.DataFrame()

# Define the initial start and end dates
start_date = datetime.strptime("2015-04-01", "%Y-%m-%d")
end_date = start_date + timedelta(days=28)

# Set the number of iterations you want to loop through
num_iterations = 124  # Approximate number of iterations to get to today

# Loop to go through each 28-day period and collect data
for i in range(num_iterations):
    
    # Format the dates as strings for the API request
    start_date_str = start_date.strftime("%Y-%m-%d")
    end_date_str = end_date.strftime("%Y-%m-%d")
    
    # Construct the payload for each 28-day period
    payload = {
        "Parameters": ["PM10", "PM2.5", "CO", "NH3", "NO", "NO2", "SO2", "OZONE", "TSPd",
                      "RAIN", "SOLAR", "TEMP", "SD1", "WDR", "WSP", "Humid", "NEPH"],                       
        "Sites": [39],   # List of site IDs
        "StartDate": start_date_str,  # Update the start date
        "EndDate": end_date_str,      # Update the end date
        "Categories": ["Averages"],   
        "SubCategories": ["Hourly"], 
        "Frequency": ["Hourly Average"]
    }

    # Set the headers for the request, if required
    headers = {
        'Content-Type': 'application/json'
    }

    # Make the POST request
    response = requests.post(url, headers=headers, data=json.dumps(payload))

    # Check if the request was successful
    if response.status_code == 200:
        # Parse the response JSON and convert it to a DataFrame
        data = response.json()
        df = pd.DataFrame(data)
        
        # Append the DataFrame to the combined DataFrame
        combined_df = pd.concat([combined_df, df], ignore_index=True)
    else:
        print(f"Error: {response.status_code} - {response.text}")
    
    # Move forward by 28 days
    start_date = end_date
    end_date = start_date + timedelta(days=28)

    # Sleep for 2 seconds between requests to avoid hitting rate limits
    print(f"Iteration {i + 1}/{num_iterations} completed. Sleeping for 2 seconds.")
    time.sleep(5)  # Pause for 5 seconds between iterations

# After the loop, combined_df contains all the data
print(combined_df.head())  # Display the first few rows of the combined DataFrame
# Out:
# Iteration 1/124 completed. Sleeping for 2 seconds.
# Iteration 2/124 completed. Sleeping for 2 seconds.
# Iteration 3/124 completed. Sleeping for 2 seconds.
# Iteration 4/124 completed. Sleeping for 2 seconds.
# Iteration 5/124 completed. Sleeping for 2 seconds.
# Iteration 6/124 completed. Sleeping for 2 seconds.
# Iteration 7/124 completed. Sleeping for 2 seconds.
# Iteration 8/124 completed. Sleeping for 2 seconds.
# Iteration 9/124 completed. Sleeping for 2 seconds.
# Iteration 10/124 completed. Sleeping for 2 seconds.
# Iteration 11/124 completed. Sleeping for 2 seconds.
# Iteration 12/124 completed. Sleeping for 2 seconds.
# Iteration 13/124 completed. Sleeping for 2 seconds.
# Iteration 14/124 completed. Sleeping for 2 seconds.
# Iteration 15/124 completed. Sleeping for 2 seconds.
# Iteration 16/124 completed. Sleeping for 2 seconds.
# Iteration 17/124 completed. Sleeping for 2 seconds.
# Iteration 18/124 completed. Sleeping for 2 seconds.
# Iteration 19/124 completed. Sleeping for 2 seconds.
# Iteration 20/124 completed. Sleeping for 2 seconds.
# Iteration 21/124 completed. Sleeping for 2 seconds.
# Iteration 22/124 completed. Sleeping for 2 seconds.
# Iteration 23/124 completed. Sleeping for 2 seconds.
# Iteration 24/124 completed. Sleeping for 2 seconds.
# Iteration 25/124 completed. Sleeping for 2 seconds.
# Iteration 26/124 completed. Sleeping for 2 seconds.
# Iteration 27/124 completed. Sleeping for 2 seconds.
# Iteration 28/124 completed. Sleeping for 2 seconds.
# Iteration 29/124 completed. Sleeping for 2 seconds.
# Iteration 30/124 completed. Sleeping for 2 seconds.
# Iteration 31/124 completed. Sleeping for 2 seconds.
# Iteration 32/124 completed. Sleeping for 2 seconds.
# Iteration 33/124 completed. Sleeping for 2 seconds.
# Iteration 34/124 completed. Sleeping for 2 seconds.
# Iteration 35/124 completed. Sleeping for 2 seconds.
# Iteration 36/124 completed. Sleeping for 2 seconds.
# Iteration 37/124 completed. Sleeping for 2 seconds.
# Iteration 38/124 completed. Sleeping for 2 seconds.
# Iteration 39/124 completed. Sleeping for 2 seconds.
# Iteration 40/124 completed. Sleeping for 2 seconds.
# Iteration 41/124 completed. Sleeping for 2 seconds.
# Iteration 42/124 completed. Sleeping for 2 seconds.
# Iteration 43/124 completed. Sleeping for 2 seconds.
# Iteration 44/124 completed. Sleeping for 2 seconds.
# Iteration 45/124 completed. Sleeping for 2 seconds.
# Iteration 46/124 completed. Sleeping for 2 seconds.
# Iteration 47/124 completed. Sleeping for 2 seconds.
# Iteration 48/124 completed. Sleeping for 2 seconds.
# Iteration 49/124 completed. Sleeping for 2 seconds.
# Iteration 50/124 completed. Sleeping for 2 seconds.
# Iteration 51/124 completed. Sleeping for 2 seconds.
# Iteration 52/124 completed. Sleeping for 2 seconds.
# Iteration 53/124 completed. Sleeping for 2 seconds.
# Iteration 54/124 completed. Sleeping for 2 seconds.
# Iteration 55/124 completed. Sleeping for 2 seconds.
# Iteration 56/124 completed. Sleeping for 2 seconds.
# Iteration 57/124 completed. Sleeping for 2 seconds.
# Iteration 58/124 completed. Sleeping for 2 seconds.
# Iteration 59/124 completed. Sleeping for 2 seconds.
# Iteration 60/124 completed. Sleeping for 2 seconds.
# Iteration 61/124 completed. Sleeping for 2 seconds.
# Iteration 62/124 completed. Sleeping for 2 seconds.
# Iteration 63/124 completed. Sleeping for 2 seconds.
# Iteration 64/124 completed. Sleeping for 2 seconds.
# Error: 502 - The specified CGI application encountered an error and the server terminated the process.
# Iteration 65/124 completed. Sleeping for 2 seconds.
# Iteration 66/124 completed. Sleeping for 2 seconds.
# Iteration 67/124 completed. Sleeping for 2 seconds.
# Iteration 68/124 completed. Sleeping for 2 seconds.
# Iteration 69/124 completed. Sleeping for 2 seconds.
# Iteration 70/124 completed. Sleeping for 2 seconds.
# Iteration 71/124 completed. Sleeping for 2 seconds.
# Iteration 72/124 completed. Sleeping for 2 seconds.
# Iteration 73/124 completed. Sleeping for 2 seconds.
# Iteration 74/124 completed. Sleeping for 2 seconds.
# Iteration 75/124 completed. Sleeping for 2 seconds.
# Iteration 76/124 completed. Sleeping for 2 seconds.
# Iteration 77/124 completed. Sleeping for 2 seconds.
# Iteration 78/124 completed. Sleeping for 2 seconds.
# Iteration 79/124 completed. Sleeping for 2 seconds.
# Iteration 80/124 completed. Sleeping for 2 seconds.
# Iteration 81/124 completed. Sleeping for 2 seconds.
# Iteration 82/124 completed. Sleeping for 2 seconds.
# Iteration 83/124 completed. Sleeping for 2 seconds.
# Iteration 84/124 completed. Sleeping for 2 seconds.
# Iteration 85/124 completed. Sleeping for 2 seconds.
# Iteration 86/124 completed. Sleeping for 2 seconds.
# Iteration 87/124 completed. Sleeping for 2 seconds.
# Iteration 88/124 completed. Sleeping for 2 seconds.
# Iteration 89/124 completed. Sleeping for 2 seconds.
# Iteration 90/124 completed. Sleeping for 2 seconds.
# Iteration 91/124 completed. Sleeping for 2 seconds.
# Iteration 92/124 completed. Sleeping for 2 seconds.
# Iteration 93/124 completed. Sleeping for 2 seconds.
# Iteration 94/124 completed. Sleeping for 2 seconds.
# Iteration 95/124 completed. Sleeping for 2 seconds.
# Iteration 96/124 completed. Sleeping for 2 seconds.
# Iteration 97/124 completed. Sleeping for 2 seconds.
# Iteration 98/124 completed. Sleeping for 2 seconds.
# Iteration 99/124 completed. Sleeping for 2 seconds.
# Iteration 100/124 completed. Sleeping for 2 seconds.
# Iteration 101/124 completed. Sleeping for 2 seconds.
# Iteration 102/124 completed. Sleeping for 2 seconds.
# Iteration 103/124 completed. Sleeping for 2 seconds.
# Iteration 104/124 completed. Sleeping for 2 seconds.
# Iteration 105/124 completed. Sleeping for 2 seconds.
# Iteration 106/124 completed. Sleeping for 2 seconds.
# Iteration 107/124 completed. Sleeping for 2 seconds.
# Iteration 108/124 completed. Sleeping for 2 seconds.
# Iteration 109/124 completed. Sleeping for 2 seconds.
# Iteration 110/124 completed. Sleeping for 2 seconds.
# Iteration 111/124 completed. Sleeping for 2 seconds.
# Iteration 112/124 completed. Sleeping for 2 seconds.
# Iteration 113/124 completed. Sleeping for 2 seconds.
# Iteration 114/124 completed. Sleeping for 2 seconds.
# Iteration 115/124 completed. Sleeping for 2 seconds.
# Iteration 116/124 completed. Sleeping for 2 seconds.
# Iteration 117/124 completed. Sleeping for 2 seconds.
# Iteration 118/124 completed. Sleeping for 2 seconds.
# Iteration 119/124 completed. Sleeping for 2 seconds.
# Iteration 120/124 completed. Sleeping for 2 seconds.
# Iteration 121/124 completed. Sleeping for 2 seconds.
# Iteration 122/124 completed. Sleeping for 2 seconds.
# Iteration 123/124 completed. Sleeping for 2 seconds.
# Iteration 124/124 completed. Sleeping for 2 seconds.
#    Site_Id                                          Parameter        Date  \
# 0       39  {'ParameterCode': 'CO', 'ParameterDescription'...  2015-04-01
# 1       39  {'ParameterCode': 'HUMID', 'ParameterDescripti...  2015-04-01
# 2       39  {'ParameterCode': 'NEPH', 'ParameterDescriptio...  2015-04-01
# 3       39  {'ParameterCode': 'NO', 'ParameterDescription'...  2015-04-01
# 4       39  {'ParameterCode': 'NO2', 'ParameterDescription...  2015-04-01
#
#    Hour HourDescription     Value AirQualityCategory DeterminingPollutant
# 0     1    12 am - 1 am  0.754289               None                 None
# 1     1    12 am - 1 am    94.199               None                 None
# 2     1    12 am - 1 am     0.232               None                 None
# 3     1    12 am - 1 am  6.026604               None                 None
# 4     1    12 am - 1 am  1.959503               GOOD                 None

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1239840 entries, 0 to 1239839
# Data columns (total 8 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   Site_Id               1239840 non-null  int64
#  1   Parameter             1239840 non-null  object
#  2   Date                  1239840 non-null  object
#  3   Hour                  1239840 non-null  int64
#  4   HourDescription       1239840 non-null  object
#  5   Value                 1134607 non-null  object
#  6   AirQualityCategory    379592 non-null   object
#  7   DeterminingPollutant  0 non-null        object
# dtypes: int64(2), object(6)
# memory usage: 75.7+ MB

# %%
df=combined_df

# %%
import pandas as pd

# Check the structure of the 'Parameter' column to ensure it's consistent
print(df['Parameter'].head())  # Check if this is indeed a dictionary or JSON-like

# Step 1: Extract 'ParameterCode' and 'ParameterDescription' from the 'Parameter' column
# We handle cases where 'Parameter' might not be a dictionary
df['ParameterCode'] = df['Parameter'].apply(lambda x: x.get('ParameterCode') if isinstance(x, dict) else None)
df['ParameterDescription'] = df['Parameter'].apply(lambda x: x.get('ParameterDescription') if isinstance(x, dict) else None)

# Step 2: Now pivot the DataFrame to have one row per time observation, with multiple columns
df_wide = df.pivot_table(index=['Site_Id', 'Date', 'Hour', 'HourDescription'],
                         columns='ParameterCode', 
                         values='Value', 
                         aggfunc='first').reset_index()

# Optional: Flatten the MultiIndex columns if necessary
df_wide.columns = [col if not isinstance(col, tuple) else col[1] for col in df_wide.columns]

# Step 3: Display the wide-format DataFrame
# Out:
# 0    {'ParameterCode': 'CO', 'ParameterDescription'...
# 1    {'ParameterCode': 'HUMID', 'ParameterDescripti...
# 2    {'ParameterCode': 'NEPH', 'ParameterDescriptio...
# 3    {'ParameterCode': 'NO', 'ParameterDescription'...
# 4    {'ParameterCode': 'NO2', 'ParameterDescription...
# Name: Parameter, dtype: object

# %%
df_wide.head()
# Out:
#    Site_Id        Date  Hour HourDescription        CO   HUMID   NEPH  \
# 0       39  2015-04-01     1    12 am - 1 am  0.754289  94.199  0.232
# 1       39  2015-04-01     2     1 am - 2 am       NaN  94.513  0.196
# 2       39  2015-04-01     3     2 am - 3 am  0.430155  95.974  0.177
# 3       39  2015-04-01     4     3 am - 4 am  0.407481   96.58  0.218
# 4       39  2015-04-01     5     4 am - 5 am  0.369815  97.003  0.198
#
#          NO       NO2     OZONE    PM10  PM2.5 RAIN      SD1       SO2  \
# 0  6.026604  1.959503    0.0493  13.925  7.381  NaN  108.103  0.096339
# 1       NaN       NaN       NaN  18.096  5.359  NaN   59.602       NaN
# 2  1.928971  1.746824  0.129325   3.914  2.542  NaN   77.922  0.041979
# 3  2.555419  1.651218  0.056325   3.088  5.263  NaN   77.073  0.064485
# 4  2.426823  1.576204  0.047325  16.753  9.678  NaN   95.759  0.057291
#
#     SOLAR    TEMP      WDR    WSP
# 0  -13.13  17.708   10.815   0.13
# 1 -12.835  18.285  325.715  0.605
# 2 -11.332  17.876  270.408   0.26
# 3 -11.606  17.231  261.068  0.109
# 4 -11.636  17.277   23.419  0.084

# %%
df_wide.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79365 entries, 0 to 79364
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Site_Id          79365 non-null  int64
#  1   Date             79365 non-null  object
#  2   Hour             79365 non-null  int64
#  3   HourDescription  79365 non-null  object
#  4   CO               74155 non-null  object
#  5   HUMID            79266 non-null  object
#  6   NEPH             78699 non-null  object
#  7   NO               74478 non-null  object
#  8   NO2              74479 non-null  object
#  9   OZONE            74962 non-null  object
#  10  PM10             78351 non-null  object
#  11  PM2.5            77521 non-null  object
#  12  RAIN             53467 non-null  object
#  13  SD1              78864 non-null  object
#  14  SO2              74279 non-null  object
#  15  SOLAR            79029 non-null  object
#  16  TEMP             79331 non-null  object
#  17  WDR              78864 non-null  object
#  18  WSP              78862 non-null  object
# dtypes: int64(2), object(17)
# memory usage: 11.5+ MB

# %%
df_wide.head()  # Check for NaNs at the top
# Out:
#    Site_Id        Date  Hour HourDescription        CO   HUMID   NEPH  \
# 0       39  2015-04-01     1    12 am - 1 am  0.754289  94.199  0.232
# 1       39  2015-04-01     2     1 am - 2 am       NaN  94.513  0.196
# 2       39  2015-04-01     3     2 am - 3 am  0.430155  95.974  0.177
# 3       39  2015-04-01     4     3 am - 4 am  0.407481   96.58  0.218
# 4       39  2015-04-01     5     4 am - 5 am  0.369815  97.003  0.198
#
#          NO       NO2     OZONE    PM10  PM2.5 RAIN      SD1       SO2  \
# 0  6.026604  1.959503    0.0493  13.925  7.381  NaN  108.103  0.096339
# 1       NaN       NaN       NaN  18.096  5.359  NaN   59.602       NaN
# 2  1.928971  1.746824  0.129325   3.914  2.542  NaN   77.922  0.041979
# 3  2.555419  1.651218  0.056325   3.088  5.263  NaN   77.073  0.064485
# 4  2.426823  1.576204  0.047325  16.753  9.678  NaN   95.759  0.057291
#
#     SOLAR    TEMP      WDR    WSP
# 0  -13.13  17.708   10.815   0.13
# 1 -12.835  18.285  325.715  0.605
# 2 -11.332  17.876  270.408   0.26
# 3 -11.606  17.231  261.068  0.109
# 4 -11.636  17.277   23.419  0.084

# %%
# Fill NaNs at the edges with forward and backward filling
df_wide.fillna(method='ffill', inplace=True)
df_wide.fillna(method='bfill', inplace=True)

# Then apply interpolation to fill NaNs between rows
df_wide.interpolate(method='linear', axis=0, inplace=True)

# Check the resulting DataFrame
print(df_wide)
# Out:
#        Site_Id        Date  Hour HourDescription        CO   HUMID   NEPH  \
# 0           39  2015-04-01     1    12 am - 1 am  0.754289  94.199  0.232
# 1           39  2015-04-01     2     1 am - 2 am  0.754289  94.513  0.196
# 2           39  2015-04-01     3     2 am - 3 am  0.430155  95.974  0.177
# 3           39  2015-04-01     4     3 am - 4 am  0.407481  96.580  0.218
# 4           39  2015-04-01     5     4 am - 5 am  0.369815  97.003  0.198
# ...        ...         ...   ...             ...       ...     ...    ...
# 79360       39  2024-10-01    20     7 pm - 8 pm  0.179125  71.596  0.238
# 79361       39  2024-10-01    21     8 pm - 9 pm  0.189102  71.044  0.253
# 79362       39  2024-10-01    22    9 pm - 10 pm  0.153507  66.722  0.203
# 79363       39  2024-10-01    23   10 pm - 11 pm  0.138774  65.168  0.183
# 79364       39  2024-10-01    24   11 pm - 12 am  0.144522  65.136  0.175
#
#              NO       NO2     OZONE    PM10   PM2.5  RAIN      SD1       SO2  \
# 0      6.026604  1.959503  0.049300  13.925   7.381   0.4  108.103  0.096339
# 1      6.026604  1.959503  0.049300  18.096   5.359   0.4   59.602  0.096339
# 2      1.928971  1.746824  0.129325   3.914   2.542   0.4   77.922  0.041979
# 3      2.555419  1.651218  0.056325   3.088   5.263   0.4   77.073  0.064485
# 4      2.426823  1.576204  0.047325  16.753   9.678   0.4   95.759  0.057291
# ...         ...       ...       ...     ...     ...   ...      ...       ...
# 79360 -0.020858  0.704050  2.415700  18.982   9.669   0.0   43.093  0.022581
# 79361 -0.008445  0.910228  2.185200  20.804   8.069   0.0   23.915  0.028463
# 79362 -0.015058  0.266607  3.020200  11.365  10.371   0.0   32.200  0.011415
# 79363 -0.018111  0.191643  3.124700  11.970   9.198   0.0   28.500  0.035242
# 79364 -0.020553  0.126235  3.205300  13.840   5.556   0.0   32.979  0.034245
#
#         SOLAR    TEMP      WDR    WSP
# 0     -13.130  17.708   10.815  0.130
# 1     -12.835  18.285  325.715  0.605
# 2     -11.332  17.876  270.408  0.260
# 3     -11.606  17.231  261.068  0.109
# 4     -11.636  17.277   23.419  0.084
# ...       ...     ...      ...    ...
# 79360  -9.107  17.073  127.767  0.915
# 79361  -7.683  17.149  157.294  1.329
# 79362  -6.816  17.461  152.108  1.479
# 79363  -7.523  17.273  149.710  1.455
# 79364  -7.392  17.063  147.951  1.245
#
# [79365 rows x 19 columns]

# %%
df_wide.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79365 entries, 0 to 79364
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Site_Id          79365 non-null  int64
#  1   Date             79365 non-null  object
#  2   Hour             79365 non-null  int64
#  3   HourDescription  79365 non-null  object
#  4   CO               79365 non-null  float64
#  5   HUMID            79365 non-null  float64
#  6   NEPH             79365 non-null  float64
#  7   NO               79365 non-null  float64
#  8   NO2              79365 non-null  float64
#  9   OZONE            79365 non-null  float64
#  10  PM10             79365 non-null  float64
#  11  PM2.5            79365 non-null  float64
#  12  RAIN             79365 non-null  float64
#  13  SD1              79365 non-null  float64
#  14  SO2              79365 non-null  float64
#  15  SOLAR            79365 non-null  float64
#  16  TEMP             79365 non-null  float64
#  17  WDR              79365 non-null  float64
#  18  WSP              79365 non-null  float64
# dtypes: float64(15), int64(2), object(2)
# memory usage: 11.5+ MB

# %%
df_wide.head()
# Out:
#    Site_Id        Date  Hour HourDescription        CO   HUMID   NEPH  \
# 0       39  2015-04-01     1    12 am - 1 am  0.754289  94.199  0.232
# 1       39  2015-04-01     2     1 am - 2 am  0.754289  94.513  0.196
# 2       39  2015-04-01     3     2 am - 3 am  0.430155  95.974  0.177
# 3       39  2015-04-01     4     3 am - 4 am  0.407481  96.580  0.218
# 4       39  2015-04-01     5     4 am - 5 am  0.369815  97.003  0.198
#
#          NO       NO2     OZONE    PM10  PM2.5  RAIN      SD1       SO2  \
# 0  6.026604  1.959503  0.049300  13.925  7.381   0.4  108.103  0.096339
# 1  6.026604  1.959503  0.049300  18.096  5.359   0.4   59.602  0.096339
# 2  1.928971  1.746824  0.129325   3.914  2.542   0.4   77.922  0.041979
# 3  2.555419  1.651218  0.056325   3.088  5.263   0.4   77.073  0.064485
# 4  2.426823  1.576204  0.047325  16.753  9.678   0.4   95.759  0.057291
#
#     SOLAR    TEMP      WDR    WSP
# 0 -13.130  17.708   10.815  0.130
# 1 -12.835  18.285  325.715  0.605
# 2 -11.332  17.876  270.408  0.260
# 3 -11.606  17.231  261.068  0.109
# 4 -11.636  17.277   23.419  0.084

# %%
df_wide['datetime'] = pd.to_datetime(df_wide['Date']) + pd.to_timedelta(df_wide['Hour'], unit='h')

# Set 'datetime' as the index
df_wide.set_index('datetime', inplace=True)
df_wide.head()
# Out:
#                      Site_Id        Date  Hour HourDescription        CO  \
# datetime
# 2015-04-01 01:00:00       39  2015-04-01     1    12 am - 1 am  0.754289
# 2015-04-01 02:00:00       39  2015-04-01     2     1 am - 2 am  0.754289
# 2015-04-01 03:00:00       39  2015-04-01     3     2 am - 3 am  0.430155
# 2015-04-01 04:00:00       39  2015-04-01     4     3 am - 4 am  0.407481
# 2015-04-01 05:00:00       39  2015-04-01     5     4 am - 5 am  0.369815
#
#                       HUMID   NEPH        NO       NO2     OZONE    PM10  \
# datetime
# 2015-04-01 01:00:00  94.199  0.232  6.026604  1.959503  0.049300  13.925
# 2015-04-01 02:00:00  94.513  0.196  6.026604  1.959503  0.049300  18.096
# 2015-04-01 03:00:00  95.974  0.177  1.928971  1.746824  0.129325   3.914
# 2015-04-01 04:00:00  96.580  0.218  2.555419  1.651218  0.056325   3.088
# 2015-04-01 05:00:00  97.003  0.198  2.426823  1.576204  0.047325  16.753
#
#                      PM2.5  RAIN      SD1       SO2   SOLAR    TEMP      WDR  \
# datetime
# 2015-04-01 01:00:00  7.381   0.4  108.103  0.096339 -13.130  17.708   10.815
# 2015-04-01 02:00:00  5.359   0.4   59.602  0.096339 -12.835  18.285  325.715
# 2015-04-01 03:00:00  2.542   0.4   77.922  0.041979 -11.332  17.876  270.408
# 2015-04-01 04:00:00  5.263   0.4   77.073  0.064485 -11.606  17.231  261.068
# 2015-04-01 05:00:00  9.678   0.4   95.759  0.057291 -11.636  17.277   23.419
#
#                        WSP
# datetime
# 2015-04-01 01:00:00  0.130
# 2015-04-01 02:00:00  0.605
# 2015-04-01 03:00:00  0.260
# 2015-04-01 04:00:00  0.109
# 2015-04-01 05:00:00  0.084
