# %%
import pandas as pd

# %%
df=pd.read_excel('air_quality/cookphilipjan11.xls')
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %%
df.head()
# Out:
#   Hourly Averages Time Range: 01/01/2011 00:00 to 01/02/2011 00:00 Unnamed: 1  \
# 0                                       Initial Data                      NaN
# 1                                               Date                     Time
# 2                                         01/01/2011                    01:00
# 3                                         01/01/2011                    02:00
# 4                                         01/01/2011                    03:00
#
#                             Unnamed: 2                             Unnamed: 3  \
# 0                                  NaN                                    NaN
# 1  COOK AND PHILLIP WDR 1h average [°]  COOK AND PHILLIP TEMP 1h average [°C]
# 2                                  NaN                                    NaN
# 3                                  NaN                                    NaN
# 4                                  NaN                                    NaN
#
# ...
